# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from src.DataAnalyzer import DataAnalyzer
from src.ExpenseAnalyzer import ExpenseAnalyzer
import pandas as pd
pd.set_option("display.max_rows", 50)        # 최대 행 수
pd.set_option("display.max_columns", None)  # 컬럼 전부 보기
pd.set_option("display.width", None)        # 줄 안잘리게
pd.set_option("display.max_colwidth", None) # 긴 문자열 안짤림
da = DataAnalyzer()
da.load_data("../data/raw/realistic_expense_1000.csv")
da.preprocess_data()
ea = ExpenseAnalyzer(da.get_analysis_data())
df = ea.compare_months(base=(2025,1),target=(2025,2))
df
